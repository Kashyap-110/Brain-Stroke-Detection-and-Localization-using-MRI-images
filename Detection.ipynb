# %% [markdown]
# # Importing the Libraries

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import torch
from IPython.display import Image
import shutil
import os
from random import choice

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda', index=0)

# %%
ML_Model = []
precision = []
recall = []
mAP = []

#function to call for storing the results
def storeResults(model, a,b,c):
    ML_Model.append(model)
    precision.append(round(a, 3))
    recall.append(round(b, 3))
    mAP.append(round(c, 3))

# %%
# !mkdir v5

# %%
cd v5
# Out:
# C:\Users\91630\OneDrive\Desktop\update\v5

# %% [markdown]
# # **YoloV5s**

# %%
from ultralytics import YOLO

# Load a model
# model = YOLO("yolov8m.yaml")  # build a new model from scratch
model = YOLO("yolov5s6u.pt")  # load a pretrained model (recommended for training)

# Use the model
results = model.train(data="C:/Users/91630/OneDrive/Desktop/update/yolo/data.yaml", epochs=30, imgsz=416)  # train the
# Out:
# New https://pypi.org/project/ultralytics/8.3.72 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.6 🚀 Python-3.10.9 torch-2.5.0+cu124 CUDA:0 (NVIDIA GeForce RTX 4090, 24564MiB)
# engine/trainer: task=detect, mode=train, model=yolov5s6u.pt, data=/mnt/c/Users/TruProjects/Desktop/Truprojects/projects/Jan25/brainstroke-os/yolo/data.yaml, epochs=30, time=None, patience=100, batch=16, imgsz=416, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=train4, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=True, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, copy_paste_mode=flip, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs/detect/train4
# Overriding model.yaml nc=80 with nc=2
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      3520  ultralytics.nn.modules.conv.Conv             [3, 32, 6, 2, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     18816  ultralytics.nn.modules.block.C3              [64, 64, 1]
#   3                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   4                  -1  2    115712  ultralytics.nn.modules.block.C3              [128, 128, 2]
#   5                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   6                  -1  3    625152  ultralytics.nn.modules.block.C3              [256, 256, 3]
#   7                  -1  1    885504  ultralytics.nn.modules.conv.Conv             [256, 384, 3, 2]
#   8                  -1  1    665856  ultralytics.nn.modules.block.C3              [384, 384, 1]
#   9                  -1  1   1770496  ultralytics.nn.modules.conv.Conv             [384, 512, 3, 2]
#  10                  -1  1   1182720  ultralytics.nn.modules.block.C3              [512, 512, 1]
#  11                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  12                  -1  1    197376  ultralytics.nn.modules.conv.Conv             [512, 384, 1, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 8]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1    813312  ultralytics.nn.modules.block.C3              [768, 384, 1, False]
#  16                  -1  1     98816  ultralytics.nn.modules.conv.Conv             [384, 256, 1, 1]
#  17                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  18             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1    361984  ultralytics.nn.modules.block.C3              [512, 256, 1, False]
#  20                  -1  1     33024  ultralytics.nn.modules.conv.Conv             [256, 128, 1, 1]
#  21                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  22             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  23                  -1  1     90880  ultralytics.nn.modules.block.C3              [256, 128, 1, False]
#  24                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  25            [-1, 20]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  26                  -1  1    296448  ultralytics.nn.modules.block.C3              [256, 256, 1, False]
#  27                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  28            [-1, 16]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  29                  -1  1    715008  ultralytics.nn.modules.block.C3              [512, 384, 1, False]
#  30                  -1  1   1327872  ultralytics.nn.modules.conv.Conv             [384, 384, 3, 2]
#  31            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  32                  -1  1   1313792  ultralytics.nn.modules.block.C3              [768, 512, 1, False]
#  33    [23, 26, 29, 32]  1   1154584  ultralytics.nn.modules.head.Detect           [2, [128, 256, 384, 512]]
# YOLOv5s6u summary: 376 layers, 13,453,784 parameters, 13,453,768 gradients, 19.4 GFLOPs
#
# Transferred 507/611 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir runs/detect/train4', view at http://localhost:6006/
# Freezing layer 'model.33.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks with YOLO11n...
# AMP: checks passed ✅
# WARNING ⚠️ imgsz=[416] must be multiple of max stride 64, updating to [448]
# train: Scanning /mnt/c/Users/TruProjects/Desktop/Truprojects/projects/Jan25/brainstroke-os/yolo/train/labels.cache... 12
# val: Scanning /mnt/c/Users/TruProjects/Desktop/Truprojects/projects/Jan25/brainstroke-os/yolo/valid/labels.cache... 1231
# Plotting labels to runs/detect/train4/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001667, momentum=0.9) with parameter groups 99 weight(decay=0.0), 108 weight(decay=0.0005), 107 bias(decay=0.0)
# TensorBoard: model graph visualization added ✅
# Image sizes 448 train, 448 val
# Using 8 dataloader workers
# Logging results to runs/detect/train4
# Starting training for 30 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/30      3.02G      1.733      2.692      1.669         24        448: 100%|██████████| 77/77 [00:10<00:00,  7.1
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 39/39 [00:04<
#                    all       1231       1238      0.437       0.49      0.438      0.188
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/30      2.93G       1.65      2.017      1.498         30        448: 100%|██████████| 77/77 [00:06<00:00, 11.5
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 39/39 [00:04<
#                    all       1231       1238      0.344      0.686      0.375      0.154
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/30      2
2
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 39/39 [00:03<
#                    all       1231       1238      0.719      0.804      0.833      0.522
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/30      2.91G      1.352     0.9821      1.333         15        448: 100%|██████████| 77/77 [00:06<00:00, 11.6
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 39/39 [00:03<
#                    all       1231       1238      0.781      0.829      0.885      0.547
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/30      2.92G      1.352      0.946      1.345         15        448: 100%|██████████| 77/77 [00:06<00:00, 11.7
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 39/39 [00:03<
#                    all       1231       1238      0.768      0.785      0.872      0.547
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/30      2.92G      1.327     0.9298      1.322         15        448: 100%|██████████| 77/77 [00:06<00:00, 12.0
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 39/39 [00:03<
#                    all       1231       1238      0.828      0.826      0.899      0.569
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/30      2.92G      1.313     0.8901      1.323         15        448: 100%|██████████| 77/77 [00:06<00:00, 11.6
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 39/39 [00:03<
#                    all       1231       1238      0.843      0.851      0.909      0.586
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/30      2.91G      1.285     0.8524      1.287         15        448: 100%|██████████| 77/77 [00:06<00:00, 12.2
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 39/39 [00:03<
#                    all       1231       1238      0.852      0.841      0.914      0.592
# 30 epochs completed in 0.132 hours.
# Optimizer stripped from runs/detect/train4/weights/last.pt, 27.3MB
# Optimizer stripped from runs/detect/train4/weights/best.pt, 27.3MB
#
# Validating runs/detect/train4/weights/best.pt...
# Ultralytics 8.3.6 🚀 Python-3.10.9 torch-2.5.0+cu124 CUDA:0 (NVIDIA GeForce RTX 4090, 24564MiB)
# YOLOv5s6u summary (fused): 277 layers, 13,436,344 parameters, 0 gradients, 19.1 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 39/39 [00:04<
#                    all       1231       1238      0.847      0.844      0.914      0.592
#                 normal        410        410      0.835      0.815      0.911      0.619
#                 stroke        821        828       0.86      0.873      0.917      0.564
# Speed: 0.1ms preprocess, 0.4ms inference, 0.0ms loss, 0.7ms postprocess per image
# Results saved to runs/detect/train4

# %%
p_yol5 = 0.847
r_yol5 = 0.844
mAP_yolo5 = 0.914

storeResults('Yolo v5s6',p_yol5,r_yol5,mAP_yolo5)

# %%
# dislaying metrics for train data
from IPython.display import Image
from IPython.display import display
x = Image(filename='runs/detect/train4/F1_curve.png')
y = Image(filename='runs/detect/train4/PR_curve.png')
z = Image(filename='runs/detect/train4/confusion_matrix.png')
display(x, y,z)

# %% [markdown]
# # Yolo v5x6

# %%
# model = YOLO("yolov8m.yaml")  # build a new model from scratch
model = YOLO("yolov5x6u.pt")  # load a pretrained model (recommended for training)

# Use the model
results = model.train(data="C:/Users/91630/OneDrive/Desktop/update/yolo/data.yaml", epochs=30, imgsz=416)  # train the
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov5x6u.pt to 'yolov5x6u.pt'...
# 100%|████████████████████████████████████████████████████████████████████████████████| 297M/297M [00:22<00:00, 13.9MB/s]
# New https://pypi.org/project/ultralytics/8.3.72 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.6 🚀 Python-3.10.9 torch-2.5.0+cu124 CUDA:0 (NVIDIA GeForce RTX 4090, 24564MiB)
# engine/trainer: task=detect, mode=train, model=yolov5x6u.pt, data=/mnt/c/Users/TruProjects/Desktop/Truprojects/projects/Jan25/brainstroke-os/yolo/data.yaml, epochs=30, time=None, patience=100, batch=16, imgsz=416, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=train5, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=True, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, copy_paste_mode=flip, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs/detect/train5
# Overriding model.yaml nc=80 with nc=2
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      8800  ultralytics.nn.modules.conv.Conv             [3, 80, 6, 2, 2]
#   1                  -1  1    115520  ultralytics.nn.modules.conv.Conv             [80, 160, 3, 2]
#   2                  -1  4    309120  ultralytics.nn.modules.block.C3              [160, 160, 4]
#   3                  -1  1    461440  ultralytics.nn.modules.conv.Conv             [160, 320, 3, 2]
#   4                  -1  8   2259200  ultralytics.nn.modules.block.C3              [320, 320, 8]
#   5                  -1  1   1844480  ultralytics.nn.modules.conv.Conv             [320, 640, 3, 2]
#   6                  -1 12  13125120  ultralytics.nn.modules.block.C3              [640, 640, 12]
#   7                  -1  1   5531520  ultralytics.nn.modules.conv.Conv             [640, 960, 3, 2]
#   8                  -1  4  11070720  ultralytics.nn.modules.block.C3              [960, 960, 4]
#   9                  -1  1  11061760  ultralytics.nn.modules.conv.Conv             [960, 1280, 3, 2]
#  10                  -1  4  19676160  ultralytics.nn.modules.block.C3              [1280, 1280, 4]
#  11                  -1  1   4099840  ultralytics.nn.modules.block.SPPF            [1280, 1280, 5]
#  12                  -1  1   1230720  ultralytics.nn.modules.conv.Conv             [1280, 960, 1, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 8]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  4  11992320  ultralytics.nn.modules.block.C3              [1920, 960, 4, False]
#  16                  -1  1    615680  ultralytics.nn.modules.conv.Conv             [960, 640, 1, 1]
#  17                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  18             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  4   5332480  ultralytics.nn.modules.block.C3              [1280, 640, 4, False]
#  20                  -1  1    205440  ultralytics.nn.modules.conv.Conv             [640, 320, 1, 1]
#  21                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  22             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  23                  -1  4   1335040  ultralytics.nn.modules.block.C3              [640, 320, 4, False]
#  24                  -1  1    922240  ultralytics.nn.modules.conv.Conv             [320, 320, 3, 2]
#  25            [-1, 20]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  26                  -1  4   4922880  ultralytics.nn.modules.block.C3              [640, 640, 4, False]
#  27                  -1  1   3687680  ultralytics.nn.modules.conv.Conv             [640, 640, 3, 2]
#  28            [-1, 16]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  29                  -1  4  11377920  ultralytics.nn.modules.block.C3              [1280, 960, 4, False]
#  30                  -1  1   8296320  ultralytics.nn.modules.conv.Conv             [960, 960, 3, 2]
#  31            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  32                  -1  4  20495360  ultralytics.nn.modules.block.C3              [1920, 1280, 4, False]
#  33    [23, 26, 29, 32]  1   4047000  ultralytics.nn.modules.head.Detect           [2, [320, 640, 960, 1280]]
# YOLOv5x6u summary: 670 layers, 144,024,760 parameters, 144,024,744 gradients, 219.1 GFLOPs
#
# Transferred 1011/1115 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir runs/detect/train5', view at http://localhost:6006/
# Freezing layer 'model.33.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks with YOLO11n...
# AMP: checks passed ✅
# WARNING ⚠️ imgsz=[416] must be multiple of max stride 64, updating to [448]
# train: Scanning /mnt/c/Users/TruProjects/Desktop/Truprojects/projects/Jan25/brainstroke-os/yolo/train/labels.cache... 12
# val: Scanning /mnt/c/Users/TruProjects/Desktop/Truprojects/projects/Jan25/brainstroke-os/yolo/valid/labels.cache... 1231
# Plotting labels to runs/detect/train5/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001667, momentum=0.9) with parameter groups 183 weight(decay=0.0), 192 weight(decay=0.0005), 191 bias(decay=0.0)
# TensorBoard: model graph visualization added ✅
# Image sizes 448 train, 448 val
# Using 8 dataloader workers
# Logging results to runs/detect/train5
# Starting training for 30 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/30      11.2G      1.821      2.615      1.844         24        448: 100%|██████████| 77/77 [00:14<00:00,  5.3
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 39/39 [00:06<
#                    all       1231       1238      0.311      0.332      0.202     0.0825
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/30      9.82G      1.822      2.033      1.745         30        448: 100%|██████████| 77/77 [00:13<00:00,  5.7
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 39/39 [00:06<
#                    all       1231       1238      0.155      0.397      0.166     0.0493
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/30       9.8G      1.791      1.782      1.667         32        448: 100%|██████████| 77/77 [00:12<00:00,  6.0
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 39/39 [00:08<
#                    all       1231       1238      0.155      0.397      0.166     0.0493
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/30      10.1G      1.737      1.698       1.64         32        448: 100%|██████████| 77/77 [00:13<00:00,  5.6
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 39/39 [00:06<
#                    all       1231       1238      0.181      0.586      0.268     0.0884
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/30      10.1G      1.736      1.655      1.672         27        448: 100%|██████████| 77/77 [00:13<00:00,  5.8
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 39/39 [00:06<
#                    all       1231       1238      0.249      0.843      0.452       0.22
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/30      9.82G      1.649      1.547      1.612         41        448: 100%|██████████| 77/77 [00:13<00:00,  5.8
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 39/39 [00:06<
#                    all       1231       1238       0.35      0.913      0.462      0.203
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/30      10.1G      1.609      1.522      1.575         35        448: 100%|██████████| 77/77 [00:13<00:00,  5.8
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 39/39 [00:06<
#                    all       1231       1238      0.415      0.873      0.485      0.245
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/30      10.1G      1.634      1.518      1.588         28        448: 100%|██████████| 77/77 [00:12<00:00,  6.1
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 39/39 [00:06<
#                    all       1231       1238       0.46      0.906      0.507      0.244
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/30      10.1G      1.607      1.501      1.569         31        448: 100%|██████████| 77/77 [00:12<00:00,  5.9
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 39/39 [00:06<
#                    all       1231       1238      0.457      0.883      0.502      0.241
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/30       9.8G      1.582      1.452      1.537         39        448: 100%|██████████| 77/77 [00:12<00:00,  5.9
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 39/39 [00:06<
#                    all       1231       1238      0.448       0.93      0.522      0.278
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/30      10.1G      1.575       1.47      1.547         25        448: 100%|██████████| 77/77 [00:12<00:00,  5.9
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 39/39 [00
ms inference, 0.0ms loss, 0.7ms postprocess per image
# Results saved to runs/detect/train5

# %%
p_yol5 = 0.731
r_yol5 = 0.819
mAP_yolo5 = 0.856

storeResults('Yolo v5x6',p_yol5,r_yol5,mAP_yolo5)

# %%
# dislaying metrics for train data
from IPython.display import Image
from IPython.display import display
x = Image(filename='runs/detect/train5/F1_curve.png')
y = Image(filename='runs/detect/train5/PR_curve.png')
z = Image(filename='runs/detect/train5/confusion_matrix.png')
display(x, y,z)

# %% [markdown]
# # YoloV8

# %%
cd C:/Users/91630/OneDrive/Desktop/update
# Out:
# C:\Users\91630\OneDrive\Desktop\update

# %%
# !mkdir v8

# %%
cd v8
# Out:
# C:\Users\91630\OneDrive\Desktop\update\v8

# %%
# Load a model
# model = YOLO("yolov8m.yaml")  # build a new model from scratch
model = YOLO("yolov8n.pt")  # load a pretrained model (recommended for training)

# Use the model
results = model.train(data="C:/Users/91630/OneDrive/Desktop/update/yolo/data.yaml", epochs=30, imgsz=416)  # train the
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8n.pt to 'yolov8n.pt'...
# 100%|███████████████████████████████████████████████████████████████████████████████████████████| 6.25M/6.25M [00:00<00:00, 63.6MB/s]
# New https://pypi.org/project/ultralytics/8.3.72 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.6 🚀 Python-3.10.9 torch-2.5.0+cu124 CUDA:0 (NVIDIA GeForce RTX 4090, 24564MiB)
# engine/trainer: task=detect, mode=train, model=yolov8n.pt, data=/mnt/c/Users/TruProjects/Desktop/Truprojects/projects/Jan25/brainstroke-os/yolo/data.yaml, epochs=30, time=None, patience=100, batch=16, imgsz=416, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=train, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=True, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, copy_paste_mode=flip, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs/detect/train
# Overriding model.yaml nc=80 with nc=2
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    431062  ultralytics.nn.modules.head.Detect           [2, [64, 128, 256]]
# Model summary: 249 layers, 2,690,598 parameters, 2,690,582 gradients, 6.9 GFLOPs
#
# Transferred 313/391 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir runs/detect/train', view at http://localhost:6006/
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks with YOLO11n...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt'...
# 100%|███████████████████████████████████████████████████████████████████████████████████████████| 5.35M/5.35M [00:00<00:00, 65.1MB/s]
# AMP: checks passed ✅
# train: Scanning /mnt/c/Users/TruProjects/Desktop/Truprojects/projects/Jan25/brainstroke-os/yolo/train/labels.cache... 1231 images, 0
# val: Scanning /mnt/c/Users/TruProjects/Desktop/Truprojects/projects/Jan25/brainstroke-os/yolo/valid/labels.cache... 1231 images, 0 ba
# Plotting labels to runs/detect/train/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001667, momentum=0.9) with parameter groups 63 weight(decay=0.0), 70 weight(decay=0.0005), 69 bias(decay=0.0)
# TensorBoard: model graph visualization added ✅
# Image sizes 416 train, 416 val
# Using 8 dataloader workers
# Logging results to runs/detect/train
# Starting training for 30 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/30      4.22G      1.721      2.737      1.666         24        416: 100%|██████████| 77/77 [00:05<00:00, 13.31it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 39/39 [00:04<00:00,  8.53i
#                    all       1231       1238      0.445      0.453      0.415      0.188
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/30      1.18G      1.604      1.925      1.466         30        416: 100%|██████████| 77/77 [00:11<00:00,  6.61it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 39/39 [00:10<00:00,  3.80i
#                    all       1231       1238      0.427       0.73      0.453        0.2
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/30      1.21G      1.616       1.77      1.437         32        416: 100%|██████████| 77/77 [00:09<00:00,  8.34it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 39/39 [00:08<00:00,  4.65i
#                    all       1231       1238      0.441      0.814      0.471      0.237
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/30      1.21G        1.6      1.708      1.431         32        416: 100%|██████████| 77/77 [00:09<00:00,  8.22it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 39/39 [00:08<00:00,  4.53i
#                    all       1231       1238      0.448      0.771      0.484      0.243
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/30      1.21G      1.584      1.608      1.419         27        416: 100%|██████████| 77/77 [00:10<00:00,  7.32it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 39/39 [00:08<00:00,  4.36i
#                    all       1231       1238       0.46      0.875      0.528      0.278
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/30      1.21G      1.529      1.509      1.361         41        416: 100%|██████████| 77/77 [00:12<00:00,  6.07it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 39/39 [00:10<00:00,  3.82i
#                    all       1231       1238      0.465      0.892       0.51       0.27
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/30      1.22G      1.495      1.468      1.353         35        416: 100%|██████████| 77/77 [00:13<00:00,  5.89it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 39/39 [00:08<00:00,  4.39i
#                    all       1231       1238      0.482       0.94      0.552      0.301
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/30      1.21G      1.496      1.458      1.358         28        416: 100%|██████████| 77/77 [00:12<00:00,  6.30it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 39/39 [00:10<00:00,  3.77i
#                    all       1231       1238      0.385      0.698      0.486      0.259
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/30      1.21G      1.485       1.42      1.353         31        416: 100%|██████████| 77/77 [00:13<00:00,  5.75it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 39/39 [00
99it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 39/39 [00:03<00:00, 10.85i
#                    all       1231       1238      0.919      0.887      0.957      0.632
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/30      1.21G       1.24     0.7679       1.24         15        416: 100%|██████████| 77/77 [00:05<00:00, 14.83it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 39/39 [00:03<00:00, 11.27i
#                    all       1231       1238      0.928      0.901      0.965      0.646
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/30      1.21G      1.221     0.7125      1.223         15        416: 100%|██████████| 77/77 [00:05<00:00, 15.16it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 39/39 [00:03<00:00, 10.43i
#                    all       1231       1238      0.938      0.915      0.966      0.655
# 30 epochs completed in 0.145 hours.
# Optimizer stripped from runs/detect/train/weights/last.pt, 5.6MB
# Optimizer stripped from runs/detect/train/weights/best.pt, 5.6MB
#
# Validating runs/detect/train/weights/best.pt...
# Ultralytics 8.3.6 🚀 Python-3.10.9 torch-2.5.0+cu124 CUDA:0 (NVIDIA GeForce RTX 4090, 24564MiB)
# Model summary (fused): 186 layers, 2,684,758 parameters, 0 gradients, 6.8 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 39/39 [00:04<00:00,  8.68i
#                    all       1231       1238      0.938      0.914      0.966      0.655
#                 normal        410        410      0.938      0.924      0.972      0.697
#                 stroke        821        828      0.939      0.905      0.961      0.613
# Speed: 0.2ms preprocess, 0.4ms inference, 0.0ms loss, 0.8ms postprocess per image
# Results saved to runs/detect/train

# %%
p_yol5 = 0.938
r_yol5 = 0.914
mAP_yolo5 = 0.966

storeResults('Yolo v8',p_yol5,r_yol5,mAP_yolo5)

# %%
x = Image(filename='runs/detect/train/F1_curve.png')
y = Image(filename='runs/detect/train/PR_curve.png')
z = Image(filename='runs/detect/train/confusion_matrix.png')
display(x, y,z)

# %% [markdown]
# # Yolo v9

# %%
cd C:/Users/91630/OneDrive/Desktop/update
# Out:
# C:\Users\91630\OneDrive\Desktop\update

# %%
# !mkdir v9

# %%
cd v9
# Out:
# C:\Users\91630\OneDrive\Desktop\update\v9

# %%
# Load a model
# model = YOLO("yolov8m.yaml")  # build a new model from scratch
model = YOLO("yolov9c.pt")

# Use the model
results = model.train(data="C:/Users/91630/OneDrive/Desktop/update/yolo/data.yaml", epochs=30, imgsz=416)  # train the
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov9c.pt to 'yolov9c.pt'...
# 100%|███████████████████████████████████████████████████████████████████████████████████████████| 49.4M/49.4M [00:01<00:00, 31.5MB/s]
# New https://pypi.org/project/ultralytics/8.3.72 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.6 🚀 Python-3.10.9 torch-2.5.0+cu124 CUDA:0 (NVIDIA GeForce RTX 4090, 24564MiB)
# engine/trainer: task=detect, mode=train, model=yolov9c.pt, data=/mnt/c/Users/TruProjects/Desktop/Truprojects/projects/Jan25/brainstroke-os/yolo/data.yaml, epochs=30, time=None, patience=100, batch=16, imgsz=416, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=train, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=True, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, copy_paste_mode=flip, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs/detect/train
# Overriding model.yaml nc=80 with nc=2
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1856  ultralytics.nn.modules.conv.Conv             [3, 64, 3, 2]
#   1                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   2                  -1  1    212864  ultralytics.nn.modules.block.RepNCSPELAN4    [128, 256, 128, 64, 1]
#   3                  -1  1    164352  ultralytics.nn.modules.block.ADown           [256, 256]
#   4                  -1  1    847616  ultralytics.nn.modules.block.RepNCSPELAN4    [256, 512, 256, 128, 1]
#   5                  -1  1    656384  ultralytics.nn.modules.block.ADown           [512, 512]
#   6                  -1  1   2857472  ultralytics.nn.modules.block.RepNCSPELAN4    [512, 512, 512, 256, 1]
#   7                  -1  1    656384  ultralytics.nn.modules.block.ADown           [512, 512]
#   8                  -1  1   2857472  ultralytics.nn.modules.block.RepNCSPELAN4    [512, 512, 512, 256, 1]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPELAN         [512, 512, 256]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1   3119616  ultralytics.nn.modules.block.RepNCSPELAN4    [1024, 512, 512, 256, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1    912640  ultralytics.nn.modules.block.RepNCSPELAN4    [1024, 256, 256, 128, 1]
#  16                  -1  1    164352  ultralytics.nn.modules.block.ADown           [256, 256]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1   2988544  ultralytics.nn.modules.block.RepNCSPELAN4    [768, 512, 512, 256, 1]
#  19                  -1  1    656384  ultralytics.nn.modules.block.ADown           [512, 512]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1   3119616  ultralytics.nn.modules.block.RepNCSPELAN4    [1024, 512, 512, 256, 1]
#  22        [15, 18, 21]  1   1412566  ultralytics.nn.modules.head.Detect           [2, [256, 512, 512]]
# YOLOv9c summary: 642 layers, 21,358,998 parameters, 21,358,982 gradients, 84.1 GFLOPs
#
# Transferred 895/973 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir runs/detect/train', view at http://localhost:6006/
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks with YOLO11n...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt'...
# 100%|███████████████████████████████████████████████████████████████████████████████████████████| 5.35M/5.35M [00:00<00:00, 64.9MB/s]
# AMP: checks passed ✅
# train: Scanning /mnt/c/Users/TruProjects/Desktop/Truprojects/projects/Jan25/brainstroke-os/yolo/train/labels.cache... 1231 images, 0
# val: Scanning /mnt/c/Users/TruProjects/Desktop/Truprojects/projects/Jan25/brainstroke-os/yolo/valid/labels.cache... 1231 images, 0 ba
# Plotting labels to runs/detect/train/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001667, momentum=0.9) with parameter groups 160 weight(decay=0.0), 167 weight(decay=0.0005), 166 bias(decay=0.0)
# TensorBoard: model graph visualization added ✅
# Image sizes 416 train, 416 val
# Using 8 dataloader workers
# Logging results to runs/detect/train
# Starting training for 30 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/30       5.2G      1.832      2.506      1.764         24        416: 100%|██████████| 77/77 [00:11<00:00,  6.57it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 39/39 [00:05<00:00,  7.27i
#                    all       1231       1238       0.31      0.388      0.225     0.0741
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/30
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/30      5.12G       1.45      1.027      1.366         15        416: 100%|██████████| 77/77 [00:09<00:00,  7.70it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 39/39 [00:04<00:00,  8.09i
#                    all       1231       1238      0.748      0.749      0.841      0.507
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/30      5.21G      1.439      1.014      1.361         15        416: 100%|██████████| 77/77 [00:09<00:00,  7.81it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 39/39 [00:04<00:00,  8.31i
#                    all       1231       1238      0.746      0.809      0.854       0.51
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/30      5.18G      1.427     0.9693      1.346         15        416: 100%|██████████| 77/77 [00:09<00:00,  7.92it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 39/39 [00:04<00:00,  8.18i
#                    all       1231       1238      0.756      0.814      0.863      0.521
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/30      5.18G      1.414     0.9568      1.347         15        416: 100%|██████████| 77/77 [00:09<00:00,  7.98it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 39/39 [00:04<00:00,  8.22i
#                    all       1231       1238      0.807      0.787      0.861      0.519
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/30      5.13G       1.38     0.9526      1.328         15        416: 100%|██████████| 77/77 [00:09<00:00,  8.06it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 39/39 [00:04<00:00,  8.26i
#                    all       1231       1238      0.784      0.828      0.889       0.55
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/30      5.18G      1.372      0.909      1.328         15        416: 100%|██████████| 77/77 [00:09<00:00,  8.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 39/39 [00:04<00:00,  8.53i
#                    all       1231       1238      0.821      0.814      0.893       0.56
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/30      5.18G      1.364     0.8944      1.309         15        416: 100%|██████████| 77/77 [00:09<00:00,  8.10it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 39/39 [00:04<00:00,  8.58i
#                    all       1231       1238      0.859      0.802        0.9      0.558
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/30      5.18G      1.346     0.8825      1.309         15        416: 100%|██████████| 77/77 [00:09<00:00,  8.01it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 39/39 [00:04<00:00,  8.15i
#                    all       1231       1238      0.862      0.842      0.925      0.585
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/30      5.13G      1.331     0.8526      1.291         15        416: 100%|██████████| 77/77 [00:09<00:00,  8.41it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 39/39 [00:04<00:00,  8.59i
#                    all       1231       1238      0.868      0.827      0.922      0.587
# 30 epochs completed in 0.168 hours.
# Optimizer stripped from runs/detect/train/weights/last.pt, 43.2MB
# Optimizer stripped from runs/detect/train/weights/best.pt, 43.2MB
#
# Validating runs/detect/train/weights/best.pt...
# Ultralytics 8.3.6 🚀 Python-3.10.9 torch-2.5.0+cu124 CUDA:0 (NVIDIA GeForce RTX 4090, 24564MiB)
# YOLOv9c summary (fused): 402 layers, 21,146,966 parameters, 0 gradients, 82.7 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 39/39 [00:05<00:00,  7.67i
#                    all       1231       1238      0.869      0.826      0.922      0.587
#                 normal        410        410      0.826      0.851      0.921      0.622
#                 stroke        821        828      0.912      0.801      0.923      0.552
# Speed: 0.1ms preprocess, 1.2ms inference, 0.0ms loss, 0.8ms postprocess per image
# Results saved to runs/detect/train

# %%
p_yol5 = 0.869
r_yol5 = 0.826
mAP_yolo5 = 0.922

storeResults('Yolo v9',p_yol5,r_yol5,mAP_yolo5)

# %%
x = Image(filename='runs/detect/train/F1_curve.png')
y = Image(filename='runs/detect/train/PR_curve.png')
z = Image(filename='runs/detect/train/confusion_matrix.png')
display(x, y,z)

# %% [markdown]
# # FasterRCNN

# %%
import os
import numpy as np
import torch
import torchvision
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor
from engine import train_one_epoch, evaluate
import utils
import transforms as T
import albumentations as A
import cv2
import time
from albumentations.pytorch.transforms import ToTensorV2
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from  sklearn.model_selection import KFold
import random
# Out:
# INFO:albumentations.check_version:A new version of Albumentations is available: 2.0.2 (you have 1.4.8). Upgrade using: pip install --upgrade albumentations

# %%
class CraterDataset(object):
    def __init__(self, root, transforms):
        self.root = root
        self.transforms = transforms
        # load all image files, sorting them to
        # ensure that they are aligned
        self.imgs = list(sorted(os.listdir(os.path.join(self.root, "images"))))
        self.annots = list(sorted(os.listdir(os.path.join(self.root, "labels"))))
        self.classes =  ['normal', 'stroke']
    # Converts boundry box formats, this version assumes single class only!
    def convert_box_cord(self,bboxs, format_from, format_to, img_shape):
        if format_from == 'normxywh':
            if format_to == 'xyminmax':
                xw = bboxs[:, (1, 3)] * img_shape[1]
                yh = bboxs[:, (2, 4)] * img_shape[0]
                xmin = xw[:, 0] - xw[:, 1] / 2
                xmax = xw[:, 0] + xw[:, 1] / 2
                ymin = yh[:, 0] - yh[:, 1] / 2
                ymax = yh[:, 0] + yh[:, 1] / 2
                coords_converted = np.column_stack((xmin, ymin, xmax, ymax))

        return coords_converted

    def __getitem__(self, idx):
        # load images and boxes
        img_path = os.path.join(self.root, "images", self.imgs[idx])
        annot_path = os.path.join(self.root, "labels", self.annots[idx])
        img = cv2.imread(img_path)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB).astype(np.float32)
        img= img/255.0

        # retrieve bbox list and format to required type,
        # if annotation file is empty, fill dummy box with label 0
        if os.path.getsize(annot_path) != 0:
            bboxs = np.loadtxt(annot_path, ndmin=2)
            bboxs = self.convert_box_cord(bboxs, 'normxywh', 'xyminmax', img.shape)
            num_objs = len(bboxs)
            bboxs = torch.as_tensor(bboxs, dtype=torch.float32)
            # there is only one class
            labels = torch.ones((num_objs,), dtype=torch.int64)
            # suppose all instances are not crowd
            iscrowd = torch.zeros((num_objs,), dtype=torch.int64)
        else:
            bboxs = torch.as_tensor([[0, 0, 640, 640]], dtype=torch.float32)
            labels = torch.zeros((1,), dtype=torch.int64)
            iscrowd = torch.zeros((1,), dtype=torch.int64)

        area = (bboxs[:, 3] - bboxs[:, 1]) * (bboxs[:, 2] - bboxs[:, 0])
        image_id = torch.tensor([idx])

        target = {}
        target["boxes"] = bboxs
        target["labels"] = labels
        target["image_id"] = image_id
        target["area"] = area
        target["iscrowd"] = iscrowd

        if self.transforms is not None:
            sample = self.transforms(image=img,
                                     bboxes=target['boxes'],
                                     labels=labels)
        img = sample['image']
        target['boxes'] = torch.tensor(sample['bboxes'])
        target['labels'] = torch.tensor(sample['labels'])
        if target['boxes'].ndim == 1:
            target['boxes'] = torch.as_tensor([[0, 0, 640, 640]], dtype=torch.float32)
            target['labels'] = torch.zeros((1,), dtype=torch.int64)
        return img, target

    def __len__(self):
        return len(self.imgs)

# %%
import ssl

ssl._create_default_https_context = ssl._create_unverified_context

# %%
def plot_img_bbox(img, target):
    # plot the image and bboxes
    # Bounding boxes are defined as follows: x-min y-min width height
    fig, a = plt.subplots(1, 1)
    fig.set_size_inches(5, 5)
    a.imshow(img.permute((1,2,0)))
    for box in (target['boxes']):
        x, y, width, height = box[0], box[1], box[2] - box[0], box[3] - box[1]
        rect = patches.Rectangle((x, y),
                                 width, height,
                                 edgecolor='b',
                                 facecolor='none',
                                 clip_on=False)
        a.annotate('stroke', (x,y-20), color='red', weight='bold',
                   fontsize=10, ha='left', va='top')

        # Draw the bounding box on top of the image
        a.add_patch(rect)
    plt.show()

# %%
def get_model_bbox(num_classes):
    # load an instance segmentation model pre-trained on COCO
    model = torchvision.models.detection.fasterrcnn_mobilenet_v3_large_fpn(pretrained=True)

    # get number of input features for the classifier
    in_features = model.roi_heads.box_predictor.cls_score.in_features
    # replace the pre-trained head with a new one
    model.roi_heads.box_predictor = FastRCNNPredictor(in_features, num_classes)

    return model

# %%
def get_transform(train):
    if train:
        return A.Compose([
            # A.Flip(p=0.5),
            # A.RandomResizedCrop(height=640,width=640,p=0.4),
            # # A.Perspective(p=0.4),
            # A.Rotate(p=0.5),
            # # A.Transpose(p=0.3),
            ToTensorV2(p=1.0)],
            bbox_params=A.BboxParams(format='pascal_voc',min_visibility=0.4, label_fields=['labels']))
    else:
        return A.Compose([ToTensorV2(p=1.0)],
                         bbox_params=A.BboxParams(format='pascal_voc', min_visibility=0.5, label_fields=['labels']))

# %%
def reset_weights(m):
  '''
    Try resetting model weights to avoid
    weight leakage.
  '''
  for layer in m.children():
    if hasattr(layer, 'reset_parameters'):
        print(f'Reset trainable parameters of layer = {layer}')
        layer.reset_parameters()

# %%
dataset = CraterDataset('yolo/train', get_transform(train=True))
# Prints an example of image with annotations
for i in random.sample(range(1, 100), 3):
    img, target = dataset[i]
    plot_img_bbox(img, target)

# %%
num_epochs = 2

# our dataset has two classes only - background and crater
num_classes = 2
# use our dataset and defined transformations
dataset = CraterDataset('yolo/train', get_transform(train=True))
dataset_test = CraterDataset('yolo/valid', get_transform(train=False))

# define training and validation data loaders
data_loader = torch.utils.data.DataLoader(
        dataset, batch_size=8, shuffle=True, num_workers=0,
    collate_fn=utils.collate_fn)

data_loader_test = torch.utils.data.DataLoader(
    dataset_test, batch_size=1, shuffle=False, num_workers=0,
    collate_fn=utils.collate_fn)

# get the model using our helper function
model = get_model_bbox(num_classes)

'''
Use this to reset all trainable weights
model.apply(reset_weights)
'''

# move model to the right device
model.to(device)

# construct an optimizer
params = [p for p in model.parameters() if p.requires_grad]
optimizer = torch.optim.SGD(params, lr=0.005,  # Feel free to play with values
                            momentum=0.9, weight_decay=0)

# Defining learning rate scheduler
lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer,
                                                step_size=20,
                                                gamma=0.2)


result_mAP = []
best_epoch = None

# Let's train!
for epoch in range(num_epochs):


    # train for one epoch, printing every 10 iterations
    train_one_epoch(model, optimizer, data_loader, device, epoch, print_freq=50)
    # update the learning rate
    lr_scheduler.step()
    # evaluate on the test dataset
    results =  evaluate(model, data_loader_test, device=device)
    # saves results of mAP @ IoU = 0.5
    result_mAP.append(results.coco_eval['bbox'].stats[1])
    #save the best model so far
    if result_mAP[-1] == max(result_mAP):
        best_save_path = os.path.join(f'bestmodel_noaug_sgd(wd=0)_8batch-epoch{epoch}.pth')
        torch.save(model.state_dict(), best_save_path)
        best_epoch = int(epoch)
        print(f'\n\nmodel from epoch number {epoch} saved!\n result is {max(result_mAP)}\n\n')

# Saving the last model
save_path = os.path.join(f'noaug_sgd_2batch-lastepoch{num_epochs-1}.pth')
torch.save(model.state_dict(), save_path)
print(f'model from last epoch(no.{num_epochs-1}) saved')
# Out:
# Epoch: [0]  [  0/226]  eta: 0:05:42  lr: 0.000950  loss: 2.2971 (2.2971)  loss_classifier: 0.7039 (0.7039)  loss_box_reg: 1.5681 (1.5681)  loss_objectness: 0.0030 (0.0030)  loss_rpn_box_reg: 0.0221 (0.0221)  time: 1.5150  data: 0.0665  max mem: 1512
# Epoch: [0]  [ 50/226]  eta: 0:00:33  lr: 0.005000  loss: 0.7197 (0.9257)  loss_classifier: 0.2773 (0.3334)  loss_box_reg: 0.4194 (0.5704)  loss_objectness: 0.0051 (0.0084)  loss_rpn_box_reg: 0.0090 (0.0135)  time: 0.1688  data: 0.0654  max mem: 1772
# Epoch: [0]  [100/226]  eta: 0:00:23  lr: 0.005000  loss: 0.7729 (0.8119)  loss_classifier: 0.3017 (0.3084)  loss_box_reg: 0.4601 (0.4849)  loss_objectness: 0.0017 (0.0065)  loss_rpn_box_reg: 0.0109 (0.0121)  time: 0.1795  data: 0.0646  max mem: 1772
# Epoch: [0]  [150/226]  eta: 0:00:13  lr: 0.005000  loss: 0.5526 (0.7605)  loss_classifier: 0.2407 (0.2939)  loss_box_reg: 0.3333 (0.4490)  loss_objectness: 0.0027 (0.0062)  loss_rpn_box_reg: 0.0096 (0.0114)  time: 0.1720  data: 0.0648  max mem: 1772
# Epoch: [0]  [200/226]  eta: 0:00:04  lr: 0.005000  loss: 0.6776 (0.7476)  loss_classifier: 0.2598 (0.2907)  loss_box_reg: 0.4112 (0.4401)  loss_objectness: 0.0024 (0.0059)  loss_rpn_box_reg: 0.0074 (0.0108)  time: 0.1713  data: 0.0642  max mem: 1772
# Epoch: [0]  [225/226]  eta: 0:00:00  lr: 0.005000  loss: 0.5279 (0.7272)  loss_classifier: 0.1929 (0.2827)  loss_box_reg: 0.2951 (0.4281)  loss_objectness: 0.0030 (0.0058)  loss_rpn_box_reg: 0.0074 (0.0106)  time: 0.1778  data: 0.0623  max mem: 1772
# Epoch: [0] Total time: 0:00:40 (0.1798 s / it)
# creating index...
# index created!
# Test:  [  0/450]  eta: 0:00:21  model_time: 0.0362 (0.0362)  evaluator_time: 0.0016 (0.0016)  time: 0.0468  data: 0.0080  max mem: 1772
# Test:  [100/450]  eta: 0:00:12  model_time: 0.0260 (0.0264)  evaluator_time: 0.0010 (0.0010)  time: 0.0356  data: 0.0078  max mem: 1772
# Test:  [200/450]  eta: 0:00:09  model_time: 0.0260 (0.0263)  evaluator_time: 0.0010 (0.0009)  time: 0.0366  data: 0.0079  max mem: 1772
# Test:  [300/450]  eta: 0:00:05  model_time: 0.0261 (0.0263)  evaluator_time: 0.0010 (0.0009)  time: 0.0366  data: 0.0077  max mem: 1772
# Test:  [400/450]  eta: 0:00:01  model_time: 0.0260 (0.0263)  evaluator_time: 0.0010 (0.0009)  time: 0.0362  data: 0.0079  max mem: 1772
# Test:  [449/450]  eta: 0:00:00  model_time: 0.0250 (0.0263)  evaluator_time: 0.0010 (0.0009)  time: 0.0361  data: 0.0080  max mem: 1772
# Test: Total time: 0:00:16 (0.0362 s / it)
# Averaged stats: model_time: 0.0250 (0.0263)  evaluator_time: 0.0010 (0.0009)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.251
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.650
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.163
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.251
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.305
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.421
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.421
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.421
#
#
# model from epoch number 0 saved!
#  result is 0.6496147546973114
#
#
# Epoch: [1]  [  0/226]  eta: 0:00:36  lr: 0.005000  loss: 0.8327 (0.8327)  loss_classifier: 0.2817 (0.2817)  loss_box_reg: 0.5296 (0.5296)  loss_objectness: 0.0144 (0.0144)  loss_rpn_box_reg: 0.0069 (0.0069)  time: 0.1629  data: 0.0639  max mem: 1772
# Epoch: [1]  [ 50/226]  eta: 0:00:29  lr: 0.005000  loss: 0.5758 (0.6117)  loss_classifier: 0.2265 (0.2452)  loss_box_reg: 0.3331 (0.3524)  loss_objectness: 0.0023 (0.0056)  loss_rpn_box_reg: 0.0082 (0.0085)  time: 0.1718  data: 0.0636  max mem: 1772
# Epoch: [1]  [100/226]  eta: 0:00:21  lr: 0.005000  loss: 0.5356 (0.5969)  loss_classifier: 0.2277 (0.2395)  loss_box_reg: 0.3189 (0.3449)  loss_objectness: 0.0031 (0.0046)  loss_rpn_box_reg: 0.0075 (0.0079)  time: 0.1701  data: 0.0625  max mem: 1772
# Epoch: [1]  [150/226]  eta: 0:00:12  lr: 0.005000  loss: 0.5970 (0.6283)  loss_classifier: 0.2502 (0.2484)  loss_box_reg: 0.3477 (0.3670)  loss_objectness: 0.0024 (0.0046)  loss_rpn_box_reg: 0.0087 (0.0083)  time: 0.1685  data: 0.0624  max mem: 1772
# Epoch: [1]  [200/226]  eta: 0:00:04  lr: 0.005000  loss: 0.6013 (0.6225)  loss_classifier: 0.2302 (0.2460)  loss_box_reg: 0.3640 (0.3637)  loss_objectness: 0.0019 (0.0046)  loss_rpn_box_reg: 0.0069 (0.0082)  time: 0.1724  data: 0.0626  max mem: 1772
# Epoch: [1]  [225/226]  eta: 0:00:00  lr: 0.005000  loss: 0.5183 (0.6143)  loss_classifier: 0.2073 (0.2439)  loss_box_reg: 0.3098 (0.3576)  loss_objectness: 0.0021 (0.0047)  loss_rpn_box_reg: 0.0058 (0.0081)  time: 0.1721  data: 0.0599  max mem: 1772
# Epoch: [1] Total time: 0:00:38 (0.1704 s / it)
# creating index...
# index created!
# Test:  [  0/450]  eta: 0:00:15  model_time: 0.0271 (0.0271)  evaluator_time: 0.0000 (0.0000)  time: 0.0350  data: 0.0079  max mem: 1772
# Test:  [100/450]  eta: 0:00:12  model_time: 0.0260 (0.0261)  evaluator_time: 0.0010 (0.0008)  time: 0.0355  data: 0.0076  max mem: 1772
# Test:  [200/450]  eta: 0:00:08  model_time: 0.0260 (0.0262)  evaluator_time: 0.0010 (0.0008)  time: 0.0357  data: 0.0077  max mem: 1772
# Test:  [300/450]  eta: 0:00:05  model_time: 0.0260 (0.0262)  evaluator_time: 0.0010 (0.0008)  time: 0.0360  data: 0.0078  max mem: 1772
# Test:  [400/450]  eta: 0:00:01  model_time: 0.0260 (0.0262)  evaluator_time: 0.0010 (0.0008)  time: 0.0361  data: 0.0078  max mem: 1772
# Test:  [449/450]  eta: 0:00:00  model_time: 0.0260 (0.0262)  evaluator_time: 0.0010 (0.0008)  time: 0.0358  data: 0.0078  max mem: 1772
# Test: Total time: 0:00:16 (0.0360 s / it)
# Averaged stats: model_time: 0.0260 (0.0262)  evaluator_time: 0.0010 (0.0008)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.212
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.575
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.136
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.212
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.262
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.394
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.394
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.394
# model from last epoch(no.1) saved

# %%
p_yol5 = 0.212
r_yol5 = 0.394
mAP_yolo5 = 0.65

storeResults('FasterRCNN',p_yol5,r_yol5,mAP_yolo5)

# %% [markdown]
# # Comparison

# %%
#creating dataframe
import pandas as pd
result = pd.DataFrame({ 'ML Model' : ML_Model,

                       'Precision': precision,
                       'Recall'   : recall,
                       'mAP' : mAP,


                      })

# %%
result
# Out:
#      ML Model  Precision  Recall    mAP
# 0   Yolo v5s6      0.847   0.844  0.914
# 1   Yolo v5x6      0.731   0.819  0.856
# 2     Yolo v8      0.938   0.914  0.966
# 3     Yolo v9      0.869   0.826  0.922
# 4  FasterRCNN      0.212   0.394  0.650

# %% [markdown]
# # Graph

# %%
import numpy as np
classifier = ML_Model
y_pos = np.arange(len(classifier))

# %% [markdown]
# # Precision

# %%
import matplotlib.pyplot as plt2
plt2.barh(y_pos, precision, align='center', alpha=0.5,color='red')
plt2.yticks(y_pos, classifier)
plt2.xlabel('Precision Score')
plt2.title('Classification Performance')
plt2.show()

# %% [markdown]
# # Recall

# %%
plt2.barh(y_pos, recall, align='center', alpha=0.5,color='yellow')
plt2.yticks(y_pos, classifier)
plt2.xlabel('Recall Score')
plt2.title('Classification Performance')
plt2.show()

# %% [markdown]
# # mAP

# %%
plt2.barh(y_pos, mAP, align='center', alpha=0.5,color='navy')
plt2.yticks(y_pos, classifier)
plt2.xlabel('mAP')
plt2.title('Classification Performance')
plt2.show()
